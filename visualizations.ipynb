# %%
import pandas as pd

df = pd.read_csv("data/airbnb.csv")

print(df.head())
# Out:
#    price_total     room_type  is_shared_room  is_private_room  max_guests  \
# 0    93.788179  Private room               0                1         2.0
# 1   822.169053  Private room               0                1         4.0
# 2   104.351833  Private room               0                1         2.0
# 3  1031.986037  Private room               0                1         4.0
# 4  1078.983564  Private room               0                1         2.0
#
#    is_superhost  is_multi_listing  is_business_listing  cleanliness_score  \
# 0             1                 1                    0               10.0
# 1             1                 0                    0                8.0
# 2             1                 0                    1                9.0
# 3             1                 0                    1                9.0
# 4             0                 0                    0               10.0
#
# ...
